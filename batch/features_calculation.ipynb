# %% [markdown]
# # Batch Features
#
# ## Problem Statement
#
# Scenario: We're a utility company providing energy to New York City.
#
# Goal: Every day, we want to accurately predict the energy demand for the next three days so that we can optimally plan our resources.
#
# Task: We will look at historic energy demand and create batch features that we can use to predict the future demand.

# %% [markdown]
# ## Prerequisites

# %%
import pandas as pd

# %% [markdown]
# ## Data
#
# Let's explore our data!

# %%
csv_file_path = 'data/energy_data.csv'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 csv_file_path = 'data/energy_data.csv'
#       2 # Load DataFrame from CSV
# ----> 3 df = pd.read_csv(csv_file_path, parse_dates=['period']).set_index('period')
#       5 # Display the DataFrame
#       6 df.head()
#
# NameError: name 'pd' is not defined

# %%
# Load DataFrame from CSV
df = pd.read_csv(csv_file_path, parse_dates=['period']).set_index('period')

# Display the DataFrame
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 # Load DataFrame from CSV
# ----> 2 df = pd.read_csv(csv_file_path, parse_dates=['period']).set_index('period')
#       4 # Display the DataFrame
#       5 df.head()
#
# NameError: name 'pd' is not defined
